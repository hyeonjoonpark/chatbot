# %%
# !pip3 install pandas
# !pip3 install sentence_transformers
# !pip3 install sklearn
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Requirement already satisfied: pandas in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (1.5.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/hyeonjoonpark/Library/Python/3.10/lib/python/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: numpy>=1.21.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pandas) (1.24.0)
# Requirement already satisfied: pytz>=2020.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pandas) (2022.7)
# Requirement already satisfied: six>=1.5 in /Users/hyeonjoonpark/Library/Python/3.10/lib/python/site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Requirement already satisfied: sentence_transformers in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (2.2.2)
# Requirement already satisfied: transformers<5.0.0,>=4.6.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from sentence_transformers) (4.25.1)
# Requirement already satisfied: tqdm in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from sentence_transformers) (4.64.1)
# Requirement already satisfied: torch>=1.6.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from sentence_transformers) (1.13.1)
# Requirement already satisfied: torchvision in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from sentence_transformers) (0.14.1)
# Requirement already satisfied: numpy in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from sentence_transformers) (1.24.0)
# Requirement already satisfied: scikit-learn in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from sentence_transformers) (1.2.0)
# Requirement already satisfied: scipy in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from sentence_transformers) (1.9.3)
# Requirement already satisfied: nltk in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from sentence_transformers) (3.8)
# Requirement already satisfied: sentencepiece in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from sentence_transformers) (0.1.97)
# Requirement already satisfied: huggingface-hub>=0.4.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from sentence_transformers) (0.11.1)
# Requirement already satisfied: packaging>=20.9 in /Users/hyeonjoonpark/Library/Python/3.10/lib/python/site-packages (from huggingface-hub>=0.4.0->sentence_transformers) (22.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from huggingface-hub>=0.4.0->sentence_transformers) (4.4.0)
# Requirement already satisfied: filelock in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from huggingface-hub>=0.4.0->sentence_transformers) (3.8.2)
# Requirement already satisfied: requests in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from huggingface-hub>=0.4.0->sentence_transformers) (2.28.1)
# Requirement already satisfied: pyyaml>=5.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from huggingface-hub>=0.4.0->sentence_transformers) (6.0)
# Requirement already satisfied: regex!=2019.12.17 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from transformers<5.0.0,>=4.6.0->sentence_transformers) (2022.10.31)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from transformers<5.0.0,>=4.6.0->sentence_transformers) (0.13.2)
# Requirement already satisfied: joblib in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from nltk->sentence_transformers) (1.2.0)
# Requirement already satisfied: click in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from nltk->sentence_transformers) (8.1.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from scikit-learn->sentence_transformers) (3.1.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from torchvision->sentence_transformers) (9.3.0)
# Requirement already satisfied: idna<4,>=2.5 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from requests->huggingface-hub>=0.4.0->sentence_transformers) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from requests->huggingface-hub>=0.4.0->sentence_transformers) (1.26.13)
# Requirement already satisfied: certifi>=2017.4.17 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from requests->huggingface-hub>=0.4.0->sentence_transformers) (2022.12.7)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from requests->huggingface-hub>=0.4.0->sentence_transformers) (2.1.1)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Requirement already satisfied: sklearn in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (0.0.post1)

# %%
import pandas as pd
from sentence_transformers import SentenceTransformer
from sklearn.metrics.pairwise import cosine_similarity

# %%
model = SentenceTransformer('jhgan/ko-sroberta-multitask')
sentences = ["학교가 어디인가요?", "저는 부산 소마고에 다니고 있습니다."]
embeddings = model.encode(sentences)
print(embeddings)
# Out:
# 2022-12-28 10:35:16.585 Load pretrained SentenceTransformer: jhgan/ko-sroberta-multitask
# 2022-12-28 10:35:17.296 Use pytorch device: cpu
# Batches: 100%|██████████| 1/1 [00:00<00:00, 17.00it/s]
# [[ 0.10478396 -0.19161423  0.03850469 ...  0.60394967  0.50577486
#   -0.73618853]
#  [ 0.10453971  0.19116944 -0.9161046  ... -0.16573648  0.2077941
#   -0.3483476 ]]

# %%
df = pd.read_csv('챗봇.csv')
df.head(10)
# Out:
#      구분                           유저                                      챗봇  \
# 0  입학홍보                소마고는 어떤 곳인가요?                       코딩 노예를 양성하는 곳입니다.
# 1  학교행사     소마고에서 하는 교내 행사는 무엇이 있나요?          해커톤, 토크콘서트, 전공동아리 발표회 등이 있습니다.
# 2  질의응답           기숙사에 라면 들고 가도 되나요?           가져가는 것은 되지만 걸리면 불이익 감수해야 합니다.
# 3  질의응답                  학교 급식 맛있나요?                  맛있을 수도 있고 맛없을 수도 있습니다.
# 4  질의응답  학교에 입학하기 전에 어떤 공부를 하면 좋을까요?                             C언어를 공부하세요.
# 5  학과안내               학과는 어떤 것이 있나요?  소프트웨어개발과와 임베디드소프트웨어과 2개의 학과로 나뉘어 있습니다.
# 6  질의응답          학교에서 이성친구 사귀어도 되나요?                              컴퓨터랑 사귀세요.
# 7  입학홍보               학교의 장점이 무엇인가요?                               장점은 없습니다.
# 8  질의응답              아침운동에는 무엇을 하나요?                   영하 6도에 나가서 자살행위를 합니다.
# 9  질의응답         학교 학생회에서는 어떤 일을 하나요?      학생들의 의견을 대변하지만 사실 실체는 권력이 1도 없습니다.
#
#                                            embedding
# 0  [-0.14356482, -0.15075034, 0.39240262, -0.1715...
# 1  [-0.01764699, -0.04563013, -0.70772165, -0.174...
# 2  [-0.048768297, -0.124055035, 0.17905493, -0.23...
# 3  [-0.2100103, -0.3372445, 0.26944378, -0.233941...
# 4  [-0.15834844, -0.16140717, 0.3492845, -0.44417...
# 5  [-0.268918, -0.24482264, 0.039036933, 0.049901...
# 6  [-1.0227345, -0.29238263, 0.0018936441, 0.1232...
# 7  [0.085755095, -0.22512873, -0.13619024, -0.258...
# 8  [-0.1792758, 0.030156048, 0.8260302, -0.259471...
# 9  [-0.11026759, 0.022239195, -0.17768516, -0.376...

# %%
df['embedding'] = df['유저'].map(lambda x: list(model.encode(x)))
df.head(10)
# Out:
# Batches: 100%|██████████| 1/1 [00:00<00:00, 18.27it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 17.98it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 18.27it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 19.53it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 17.99it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 19.10it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 17.69it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 20.24it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 18.36it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 20.61it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 19.19it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 19.04it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 17.33it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 16.19it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 16.66it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 16.56it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 17.68it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 18.32it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 19.39it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 17.01it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 14.91it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 17.02it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 17.61it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 17.63it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 16.79it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 19.24it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 17.95it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 18.16it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 19.33it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 18.14it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 18.46it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 20.16it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 20.49it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 17.98it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 19.55it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 19.83it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 19.59it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 18.71it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 18.06it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 20.14it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 18.37it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 16.44it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 19.04it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 23.00it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 18.78it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 19.72it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 20.27it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 18.95it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 19.30it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 20.58it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 21.46it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 17.65it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 19.94it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 18.66it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 19.87it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 18.56it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 21.15it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 20.56it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 21.18it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 18.64it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 19.81it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 21.18it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 20.29it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 20.64it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 21.65it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 22.00it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 20.23it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 17.71it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 20.82it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 19.01it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 20.79it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 19.21it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 20.41it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 18.04it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 21.02it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 18.60it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 19.53it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 22.77it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 21.47it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 18.85it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 19.35it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 20.46it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 23.05it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 23.03it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 23.27it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 19.93it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 19.37it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 19.49it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 20.37it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 20.22it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 19.58it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 20.36it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 21.05it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 19.22it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 18.68it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 20.00it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 19.39it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 18.60it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 19.55it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 20.88it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 19.31it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 20.04it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 23.10it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 21.52it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 23.22it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 20.03it/s]
#      구분                           유저                                      챗봇  \
# 0  입학홍보                소마고는 어떤 곳인가요?                       코딩 노예를 양성하는 곳입니다.
# 1  학교행사     소마고에서 하는 교내 행사는 무엇이 있나요?          해커톤, 토크콘서트, 전공동아리 발표회 등이 있습니다.
# 2  질의응답           기숙사에 라면 들고 가도 되나요?           가져가는 것은 되지만 걸리면 불이익 감수해야 합니다.
# 3  질의응답                  학교 급식 맛있나요?                  맛있을 수도 있고 맛없을 수도 있습니다.
# 4  질의응답  학교에 입학하기 전에 어떤 공부를 하면 좋을까요?                             C언어를 공부하세요.
# 5  학과안내               학과는 어떤 것이 있나요?  소프트웨어개발과와 임베디드소프트웨어과 2개의 학과로 나뉘어 있습니다.
# 6  질의응답          학교에서 이성친구 사귀어도 되나요?                              컴퓨터랑 사귀세요.
# 7  입학홍보               학교의 장점이 무엇인가요?                               장점은 없습니다.
# 8  질의응답              아침운동에는 무엇을 하나요?                   영하 6도에 나가서 자살행위를 합니다.
# 9  질의응답         학교 학생회에서는 어떤 일을 하나요?      학생들의 의견을 대변하지만 사실 실체는 권력이 1도 없습니다.
#
#                                            embedding
# 0  [-0.14356482, -0.15075034, 0.39240262, -0.1715...
# 1  [-0.01764699, -0.04563013, -0.70772165, -0.174...
# 2  [-0.048768297, -0.124055035, 0.17905493, -0.23...
# 3  [-0.2100103, -0.3372445, 0.26944378, -0.233941...
# 4  [-0.15834844, -0.16140717, 0.3492845, -0.44417...
# 5  [-0.268918, -0.24482264, 0.039036933, 0.049901...
# 6  [-1.0227345, -0.29238263, 0.0018936441, 0.1232...
# 7  [0.085755095, -0.22512873, -0.13619024, -0.258...
# 8  [-0.1792758, 0.030156048, 0.8260302, -0.259471...
# 9  [-0.11026759, 0.022239195, -0.17768516, -0.376...

# %%
df.to_csv('챗봇.csv', index = False)

# %%
test = '안녕'
embedding = model.encode(test)
df['distance'] = df['embedding'].map(lambda x: cosine_similarity([embedding], [x]).squeeze())
df.head(10)
# Out:
# Batches: 100%|██████████| 1/1 [00:00<00:00, 22.82it/s]
#      구분                           유저                                      챗봇  \
# 0  입학홍보                소마고는 어떤 곳인가요?                       코딩 노예를 양성하는 곳입니다.
# 1  학교행사     소마고에서 하는 교내 행사는 무엇이 있나요?          해커톤, 토크콘서트, 전공동아리 발표회 등이 있습니다.
# 2  질의응답           기숙사에 라면 들고 가도 되나요?           가져가는 것은 되지만 걸리면 불이익 감수해야 합니다.
# 3  질의응답                  학교 급식 맛있나요?                  맛있을 수도 있고 맛없을 수도 있습니다.
# 4  질의응답  학교에 입학하기 전에 어떤 공부를 하면 좋을까요?                             C언어를 공부하세요.
# 5  학과안내               학과는 어떤 것이 있나요?  소프트웨어개발과와 임베디드소프트웨어과 2개의 학과로 나뉘어 있습니다.
# 6  질의응답          학교에서 이성친구 사귀어도 되나요?                              컴퓨터랑 사귀세요.
# 7  입학홍보               학교의 장점이 무엇인가요?                               장점은 없습니다.
# 8  질의응답              아침운동에는 무엇을 하나요?                   영하 6도에 나가서 자살행위를 합니다.
# 9  질의응답         학교 학생회에서는 어떤 일을 하나요?      학생들의 의견을 대변하지만 사실 실체는 권력이 1도 없습니다.
#
#                                            embedding  distance
# 0  [-0.14356482, -0.15075034, 0.39240262, -0.1715...  0.134596
# 1  [-0.01764699, -0.04563013, -0.70772165, -0.174...  0.098180
# 2  [-0.048768297, -0.124055035, 0.17905493, -0.23...  0.201944
# 3  [-0.2100103, -0.3372445, 0.26944378, -0.233941...  0.288433
# 4  [-0.15834844, -0.16140717, 0.3492845, -0.44417...  0.126732
# 5  [-0.268918, -0.24482264, 0.039036933, 0.049901...  0.318905
# 6  [-1.0227345, -0.29238263, 0.0018936441, 0.1232...  0.301951
# 7  [0.085755095, -0.22512873, -0.13619024, -0.258...  0.242590
# 8  [-0.1792758, 0.030156048, 0.8260302, -0.259471...  0.256182
# 9  [-0.11026759, 0.022239195, -0.17768516, -0.376...  0.264543

# %%
answer = df.loc[df['distance'].idxmax()]
print(answer['구분'])
print(answer['유저'])
print(answer['챗봇'])
print(answer['distance'])
# Out:
# 인사
# 안녕하세요.
# 안녕 안한데요?
# 0.7515116930007935

# %%
import streamlit as st
st.title("Title")
st.header("Header")
st.subheader("Sub Header")
st.write("Helllo World!")
